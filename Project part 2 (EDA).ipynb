# %% [markdown]
# # PROJECT PART 2 (EDA)

# %% [markdown]
# # Loading libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, json, math, time
# to make API calls
import tmdbsimple as tmdb
from tqdm.notebook import tqdm_notebook

# %%
#Load in data
Movies_2000 = pd.read_csv("/Users/dell/Documents/DATA/_final_tmdb_data2000.csv.gz")

Movies_2000.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
# ...

# %%
#Loading in data
movies_2001 = pd.read_csv("/Users/dell/Documents/DATA/_final_tmdb_data2001.csv.gz")

# %%
movies_2001.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
# 4  tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
# 4   1000000.0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...      NaN
#
# ...

# %%
#use concat to combine the dataframes
movies_comb= pd.concat([Movies_2000, movies_2001])

# %%
pd.set_option('display.max_columns', None)
movies_comb.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
#          id original_language   original_title  \
# ...

# %% [markdown]
# #### Create filters to slice out rows with a budget and revenue over 0

# %%
budget_filter= movies_comb['budget']>0 
#create budget filter

# %%
budget_filter.sum()
# Out:
# 590

# %% [markdown]
# #### 590 movies had valid budget information

# %%
revenue_filter = movies_comb['revenue']>0

# %%
revenue_filter.sum()
# Out:
# 484

# %% [markdown]
# #### 484 movies have revenue from the combined df.

# %%
filters_combined = budget_filter & revenue_filter

# %%
movies_comb = movies_comb.loc[filters_combined]

# %%
movies_comb.head()
# Out:
#       imdb_id  adult                     backdrop_path  \
# 4   tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 11  tt0120467    0.0  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# 13  tt0120630    0.0  /sivJXJ8JvVVSRaaBnHgzOboNBRQ.jpg
# 16  tt0120753    0.0  /3vUkQpnwbsFEQlMh9EORpvKJfpo.jpg
# 17  tt0120755    0.0  /24DZfupDlhXeTchmcOkoGRhP5Vg.jpg
#
#                                 belongs_to_collection       budget  \
# 4                                                 NaN     150000.0
# 11                                                NaN     120000.0
# 13  {'id': 718551, 'name': 'Chicken Run Collection...   45000000.0
# 16                                                NaN    8000000.0
# 17  {'id': 87359, 'name': 'Mission: Impossible Col...  125000000.0
#
#                                                genres homepage       id  \
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN    843.0
# 11  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...      NaN  19085.0
# ...

# %%
pg_13 = movies_comb['certification'] =='PG-13'
pg_13.sum()
# Out:
# 133

# %% [markdown]
# #### 133 movies are categorized as pg13

# %%
rated_R = movies_comb['certification']== 'R'
rated_R.sum()
# Out:
# 152

# %% [markdown]
# #### 152 movies are categorized as rated R

# %%
rated_G = movies_comb['certification']== 'G'
rated_G.sum()
# Out:
# 13

# %% [markdown]
# #### 13 movies are categorized as rated G

# %%
PG = movies_comb['certification']== 'PG'
PG.sum()
# Out:
# 34

# %% [markdown]
# #### 34 movies were categorized as PG

# %% [markdown]
# #### What is the average revenue per certification category?

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
movies_comb[['revenue','certification']].groupby('certification').mean()
# Out:
#                    revenue
# certification
# G             133216881.69
# NR             22122566.43
# PG            129357208.41
# PG-13         114034405.13
# R              51633435.42

# %% [markdown]
# #### What is the average budget per certification category?

# %%
movies_comb[['budget','certification']].groupby('certification').mean()
# Out:
#                    budget
# certification
# G             44000000.00
# NR            13528571.43
# PG            51013153.94
# PG-13         48303739.75
# R             27707987.17
